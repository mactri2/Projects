# %% [markdown]
# ## Import

# %%
import requests
import json

import pandas as pd

# %% [markdown]
# # IGDB Database

# %% [markdown]
# API Limit
# * 50k requests
# * Webhooks
# * 500 results per-page limit
# * 5000 Offset limit
# * CORS support (coming soon)
# * Game Achievements
# * External IDs
# * Multi-Querying
#
# Documentation
# https://api-docs.igdb.com/#about

# %% [markdown]
# ## Games

# %% [markdown]
# ### Since many games exist on both the PS4 and Xbox One and to bypass the 5000 offset limit, only PS4 and Xbox One games are included in the first query

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games = pd.DataFrame(data)
games.head()
# Out:
#        id  category  collection    cover  created_at  first_release_date  \
# 0  118704         0       275.0  82848.0  1558051200        1.546214e+09
# 1  118916         0      2693.0  81533.0  1558483200        1.509581e+09
# 2    6273         0       100.0  80938.0  1398038400        9.904032e+08
# 3    8959         0      2293.0  89239.0  1423094400        1.371082e+09
# 4   99735         0      2693.0  81563.0  1524960000        1.494461e+09
#
#   game_modes   genres                   involved_companies  \
# 0     [1, 2]      [4]                              [85711]
# 1     [1, 2]      [4]                              [84571]
# 2  [1, 2, 4]      [5]  [14942, 14943, 20453, 20454, 20455]
# 3        [1]  [8, 32]         [44773, 44774, 44775, 44776]
# 4     [1, 2]      [4]                              [84618]
#
#                                   name  ...   videos  bundles  hypes  \
# 0           TEKKEN 7: Ultimate Edition  ...      NaN      NaN    NaN
# ...

# %% [markdown]
# ## Games Offset 500

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_2 = pd.DataFrame(data)
games_2.head()
# Out:
#        id age_ratings  aggregated_rating  aggregated_rating_count  category  \
# 0    8818     [15030]          73.333333                      3.0         0
# 1   30392         NaN                NaN                      NaN         0
# 2  118919         NaN                NaN                      NaN         1
# 3   82408     [20697]                NaN                      NaN         0
# 4   90082     [22737]          55.000000                      7.0         1
#
#    collection    cover  created_at                          external_games  \
# 0      1193.0   9933.0  1422403200  [12661, 78115, 117153, 210934, 246891]
# 1         NaN  43299.0  1495497600                                     NaN
# 2         NaN  74558.0  1558483200                                     NaN
# 3         NaN  60701.0  1516320000                                [211023]
# 4       103.0  72774.0  1520380800                                     NaN
#
# ...

# %% [markdown]
# ## Games Offset 1000

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 1000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_3 = pd.DataFrame(data)
games_3.head()
# Out:
#        id     age_ratings  category  collection    cover  created_at  \
# 0   99509         [25882]         0      2693.0  81546.0  1524960000
# 1  116417         [25397]         0         NaN  74976.0  1553040000
# 2   11816             NaN         0      1578.0  80980.0  1440720000
# 3  103845             NaN         0         NaN  72219.0  1529539200
# 4   28242  [12582, 12583]         0      5464.0  22059.0  1493164800
#
#    first_release_date  franchise franchises game_modes  ...  \
# 0        1.497485e+09     1008.0     [1008]        [1]  ...
# 1        1.567728e+09        NaN        NaN        [1]  ...
# 2        1.489622e+09        NaN        NaN        [1]  ...
# 3        1.499126e+09        NaN        NaN        [1]  ...
# 4        1.496102e+09        NaN        NaN        [1]  ...
#
#                   videos alternative_names game_engines multiplayer_modes  \
# 0                    NaN               NaN          NaN               NaN
# ...

# %% [markdown]
# ## Games Offset 1500

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 1500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_4 = pd.DataFrame(data)
games_4.head()
# Out:
#        id     age_ratings  aggregated_rating  aggregated_rating_count  \
# 0   20393         [21095]               60.0                      1.0
# 1   97257             NaN                NaN                      NaN
# 2  106807  [25709, 25710]                NaN                      NaN
# 3  115673             NaN                NaN                      NaN
# 4    1214          [6867]                NaN                      NaN
#
#    category    cover  created_at                  external_games  \
# 0         0  63465.0  1468540800  [5185, 307701, 312877, 576947]
# 1         0  88439.0  1524441600              [1182742, 1775253]
# 2         0  73939.0  1533340800     [1617221, 1709934, 1728314]
# 3         0  81654.0  1551398400                             NaN
# 4         0  78836.0  1341705600                [155318, 294878]
#
#    first_release_date game_modes  ... franchises multiplayer_modes status  \
# 0        1.456445e+09        [1]  ...        NaN               NaN    NaN
# ...

# %% [markdown]
# ## Games Offset 2000

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 2000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_5 = pd.DataFrame(data)
games_5.head()
# Out:
#        id  category  collection    cover  created_at  first_release_date  \
# 0  125126         0        18.0  83336.0  1572134400        1.538698e+09
# 1   62324         0       785.0  42309.0  1505001600        1.397002e+09
# 2   11186         0        66.0  15107.0  1434412800        1.476144e+09
# 3    7268         0       980.0  69606.0  1402012800        1.383782e+09
# 4  103292         0        66.0  81895.0  1528588800        1.568074e+09
#
#    franchise franchises    genres     involved_companies  ...  \
# 0      571.0      [571]  [12, 31]         [86274, 86275]  ...
# 1        NaN        NaN      [14]                    NaN  ...
# 2        NaN        NaN       [5]  [36483, 49006, 49007]  ...
# 3     1180.0     [1180]  [12, 31]  [21046, 21047, 21048]  ...
# 4     1276.0     [1276]   [5, 31]         [82790, 82791]  ...
#
#                                               videos  \
# 0                                                NaN
# ...

# %% [markdown]
# ## Games Offset 2500

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 2500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_6 = pd.DataFrame(data)
games_6.head()
# Out:
#        id     age_ratings  aggregated_rating  aggregated_rating_count  \
# 0  120976  [25131, 25132]               40.0                      3.0
# 1   18285             NaN                NaN                      NaN
# 2  119257             NaN                NaN                      NaN
# 3   26090             NaN                NaN                      NaN
# 4   33309         [21012]                NaN                      NaN
#
#   alternative_names  category    cover  created_at  first_release_date  \
# 0    [27172, 28038]         6  85249.0  1563667200        1.543882e+09
# 1               NaN         0  55292.0  1457481600                 NaN
# 2           [24914]         0  79360.0  1559865600        1.609373e+09
# 3               NaN         1  19123.0  1480291200        1.384474e+09
# 4               NaN         0  84946.0  1495670400        1.458000e+09
#
#   game_modes  ... franchise franchises artworks time_to_beat  bundles  \
# ...

# %% [markdown]
# ## Games Offset 3000

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 3000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_7 = pd.DataFrame(data)
games_7.head()
# Out:
#       id     age_ratings  aggregated_rating  aggregated_rating_count  \
# 0  26499         [11150]             65.000                      3.0
# 1  11489   [7949, 10456]             66.875                      9.0
# 2  19082  [10839, 12379]             77.500                      6.0
# 3  52030         [24297]             50.000                      1.0
# 4  36662         [20869]             54.125                     20.0
#
#   alternative_names  category  collection    cover  created_at  \
# 0            [7913]         0      2570.0  19718.0  1481846400
# 1     [6074, 11537]         0      3898.0  10823.0  1438387200
# 2               NaN         0      3057.0  82071.0  1462752000
# 3            [9235]         0         NaN  30547.0  1501027200
# 4               NaN         0        12.0  93670.0  1496361600
#
#                              external_games  ...  game_engines bundles  \
# 0                         [103453, 1189169]  ...           NaN     NaN
# ...

# %% [markdown]
# ## Games Offset 3500

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 3500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_8 = pd.DataFrame(data)
games_8.head()
# Out:
#       id             alternative_names  category    cover  created_at  \
# 0  86270                       [25944]         0  68043.0  1517616000
# 1   4656                           NaN         0  78579.0  1390953600
# 2  21599                           NaN         0  86632.0  1469491200
# 3  93746  [21910, 21911, 21912, 27620]         0  86639.0  1521331200
# 4  14368                       [29352]         0  17980.0  1445990400
#
#                             external_games  first_release_date game_engines  \
# 0                                [1602492]        1.609373e+09         [13]
# 1  [11632, 76560, 210260, 268284, 1369004]        1.255392e+09          NaN
# 2    [8318, 78426, 106083, 211094, 247471]        1.474502e+09         [13]
# 3               [578006, 1041679, 1708297]        1.538006e+09          NaN
# 4                          [15208, 111214]        1.476317e+09          NaN
#
#      game_modes        genres  ...  version_parent version_title artworks  \
# ...

# %% [markdown]
# ## Games Offset 4000

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 4000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
games_9 = pd.DataFrame(data)
games_9.head()
# Out:
#        id     age_ratings artworks  category    cover  created_at  \
# 0   20909         [24361]   [6812]         0  72505.0  1469059200
# 1   37026         [23960]      NaN         0  90192.0  1497139200
# 2  105629             NaN      NaN         0  68770.0  1532044800
# 3   18528  [16653, 16654]      NaN         0  28888.0  1459296000
# 4   13187    [7629, 7630]      NaN         0  75349.0  1444089600
#
#                                    external_games  first_release_date  \
# 0                          [2072, 186848, 254223]        1.505347e+09
# 1                      [335501, 1617863, 1701376]        1.548202e+09
# 2                     [1602497, 1611789, 1617527]        1.541462e+09
# 3  [9376, 127379, 224107, 231043, 290067, 368217]        1.277251e+09
# 4                 [10364, 111844, 210558, 246729]        1.430352e+09
#
#   game_modes       genres  ...  bundles parent_game expansions dlcs  \
# 0        [1]     [31, 32]  ...      NaN         NaN        NaN  NaN
# ...

# %% [markdown]
# ## Games Offset 4500

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49);\noffset 4500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 491

# %%
games_10 = pd.DataFrame(data)
games_10.head()
# Out:
#        id     age_ratings  aggregated_rating  aggregated_rating_count  \
# 0   27441         [25180]          85.250000                      8.0
# 1   11667  [22526, 22527]          84.000000                     12.0
# 2  103286  [23895, 23896]          82.142857                      8.0
# 3   11213   [9024, 21527]          59.842105                     20.0
# 4   10949  [21329, 21330]          79.625000                      9.0
#
#    category    cover  created_at      dlcs                  external_games  \
# 0         0  71109.0  1488240000  [128191]      [103415, 1690419, 1706908]
# 1         0  89761.0  1439510400  [115781]                       [1592699]
# 2         0  75668.0  1528588800       NaN                       [1685367]
# 3         0  86077.0  1434412800       NaN        [111723, 189345, 245347]
# 4         0  75797.0  1433203200       NaN  [13180, 78523, 140743, 293525]
#
#    first_release_date  ... version_parent       version_title  franchise  \
# ...

# %% [markdown]
# Note: Realized the offset limit is 5000 and there are more than 5000 games across the platforms. Switching gear to grabbing data from PS4 and Xbox One since there are duplicate games on PS4 and Xbox One and the Nintendo Switch database

# %% [markdown]
# ## Merge PS4 & Xbox One Dataframes

# %%
ps4_xbox1 = pd.concat([games,
           games_2,
           games_3,
           games_4,
           games_5,
           games_6,
           games_7,
           games_8,
           games_9,
           games_10])
ps4_xbox1
# Out:
# /Users/tringuyen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.
#         age_ratings  aggregated_rating  aggregated_rating_count  \
# 0               NaN                NaN                      NaN
# 1           [25875]                NaN                      NaN
# 2     [3531, 11453]          70.000000                      2.0
# 3    [11164, 11165]          88.000000                      3.0
# 4           [25896]                NaN                      NaN
# ..              ...                ...                      ...
# 486  [13157, 21310]          89.434783                     26.0
# ...

# %% [markdown]
# ## Nintendo Switch Games

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = 130;\n"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
switch = pd.DataFrame(data)
switch.head()
# Out:
#        id  category    cover  created_at  first_release_date  franchise  \
# 0   68354         0  67185.0  1505952000        1.530317e+09     1008.0
# 1  115279         0      NaN  1550016000        1.609373e+09      546.0
# 2   51518         0  27989.0  1500422400        1.500509e+09        NaN
# 3   53790         3  89381.0  1501545600        1.511827e+09       29.0
# 4  110350         0      NaN  1537833600        1.552608e+09        NaN
#
#   franchises game_modes    genres     involved_companies  ... game_engines  \
# 0     [1008]     [1, 2]      [33]                [54507]  ...          NaN
# 1      [546]        [1]      [12]  [74456, 74457, 74458]  ...          NaN
# 2        NaN        [1]   [9, 25]         [52278, 52279]  ...          NaN
# 3       [29]  [1, 2, 3]   [5, 31]                [52623]  ...         [14]
# 4        NaN        [1]  [13, 32]                [75059]  ...          NaN
#
#   multiplayer_modes artworks  bundles expansions parent_game time_to_beat  \
# ...

# %% [markdown]
# ## Nintendo Switch Games

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = 130;\noffset 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 98

# %%
switch_2 = pd.DataFrame(data)
switch_2.head()
# Out:
#        id age_ratings  category    cover  created_at  first_release_date  \
# 0  129951     [27183]         0  92491.0  1581638400        1.581638e+09
# 1  118783         NaN         0  92489.0  1558310400        1.581638e+09
# 2  129787         NaN         0  91696.0  1581292800        1.579046e+09
# 3  129952         NaN         0  92493.0  1581638400        1.581638e+09
# 4  129955         NaN         0  92498.0  1581638400        1.581552e+09
#
#   game_modes            genres involved_companies  \
# 0  [1, 2, 4]  [10, 13, 14, 33]            [93103]
# 1        [1]      [31, 32, 33]     [93098, 93099]
# 2        [1]          [15, 33]            [92716]
# 3        [1]           [8, 33]     [93104, 93105]
# 4     [1, 2]              [33]            [93112]
#
#                                        name  ... parent_game  \
# 0                           Speedway Racing  ...         NaN
# 1  The Incredible Adventures of Super Panda  ...         NaN
# ...

# %% [markdown]
# ## Merge Nintendo Switch Games

# %%
switch_final = pd.concat([switch,switch_2])
# Out:
# /Users/tringuyen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
switch_final.to_csv('../datasets/switch.csv')

# %% [markdown]
# ## Merge Games Dataframes

# %%
games_final = pd.concat([ps4_xbox1,switch_final])

# %%
games_final.to_csv('../datasets/games_raw.csv',index=False)

# %% [markdown]
# ## Genres

# %%
url = "https://api-v3.igdb.com/genres"

payload = "fields *;\nlimit 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 21

# %%
genres = pd.DataFrame(data)
genres.head()
# Out:
#    id  created_at         name         slug  updated_at  \
# 0  13  1297555200    Simulator    simulator  1323216000
# 1  24  1300924800     Tactical     tactical  1323216000
# 2  26  1301961600  Quiz/Trivia  quiz-trivia  1323216000
# 3   4  1297555200     Fighting     fighting  1323216000
# 4  15  1297555200     Strategy     strategy  1323216000
#
#                                        url
# 0    https://www.igdb.com/genres/simulator
# 1     https://www.igdb.com/genres/tactical
# 2  https://www.igdb.com/genres/quiz-trivia
# 3     https://www.igdb.com/genres/fighting
# 4     https://www.igdb.com/genres/strategy

# %%
#copy and paste into genre df to map
genres['id'].values
# Out:
# array([13, 24, 26,  4, 15, 31, 12,  5,  7, 32, 16, 30,  9, 11, 25, 34,  8,
#        10, 14, 33,  2])

# %%
#copy and paste into genre df to map
genres['name'].values
# Out:
# array(['Simulator', 'Tactical', 'Quiz/Trivia', 'Fighting', 'Strategy',
#        'Adventure', 'Role-playing (RPG)', 'Shooter', 'Music', 'Indie',
#        'Turn-based strategy (TBS)', 'Pinball', 'Puzzle',
#        'Real Time Strategy (RTS)', "Hack and slash/Beat 'em up",
#        'Visual Novel', 'Platform', 'Racing', 'Sport', 'Arcade',
#        'Point-and-click'], dtype=object)

# %% [markdown]
# ## PS4 Only Games

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = 48;\n"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 427

# %%
games_ps4 = pd.DataFrame(data)
games_ps4.head()
# Out:
#        id  category  created_at  first_release_date game_modes  hypes  \
# 0  116796         0  1553904000        1.576109e+09        [1]    2.0
# 1   24219         0  1474502400        1.444262e+09        NaN    NaN
# 2   42956         0  1499040000        1.469578e+09        NaN    NaN
# 3   25975         1  1480032000        1.435018e+09        [1]    NaN
# 4   25997         1  1480032000        1.433462e+09        [1]    NaN
#
#   involved_companies keywords  \
# 0            [76781]  [16753]
# 1                NaN      NaN
# 2                NaN      NaN
# 3     [89554, 89555]      NaN
# 4     [89552, 89553]      NaN
#
#                                                 name platforms  ...  \
# 0              Project Sakura Wars - Limited Edition      [48]  ...
# 1               Tearaway: Unfolded - Crafted Edition      [48]  ...
# 2  Star Ocean: Integrity and Faithlessness Limite...      [48]  ...
# 3  Batman: Arkham Knight - PlayStation Exclusive ...      [48]  ...
# ...

# %% [markdown]
# ## XBox One Only Games

# %%
url = "https://api-v3.igdb.com/games"

payload = "fields *;\nlimit 500;\nwhere platforms = 49;\n"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 219

# %%
games_xbox1 = pd.DataFrame(data)
games_xbox1.head()
# Out:
#       id  category    cover  created_at             external_games  \
# 0  82545         0  60678.0  1516406400                   [210515]
# 1  82416         0  58506.0  1516320000                   [210911]
# 2  20229         0  82322.0  1468281600                   [211133]
# 3  82538         0  60689.0  1516406400                   [210623]
# 4   4757         0  84364.0  1391212800  [127308, 210404, 1185453]
#
#    first_release_date              genres  \
# 0        1.448410e+09                [33]
# 1        1.493078e+09                 NaN
# 2        1.404173e+09  [2, 5, 10, 31, 33]
# 3        1.479859e+09                 NaN
# 4        1.385078e+09                 [5]
#
#                                             keywords  \
# 0                                       [617, 17215]
# 1                                     [16828, 16894]
# 2                                                NaN
# 3                                                NaN
# ...

# %% [markdown]
# ## Platforms

# %%
import requests

url = "https://api-v3.igdb.com/platforms"

payload = "fields *;\nlimit 500;\nsort id;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)
# Out:
# [
#   {
#     "id": 3,
#     "abbreviation": "Linux",
#     "alternative_name": "GNU/Linux",
#     "category": 4,
#     "created_at": 1297555200,
#     "name": "Linux",
#     "platform_logo": 33,
#     "product_family": 4,
#     "slug": "linux",
#     "summary": "Linux is a free and open-source (FOSS/FLOSS) Operating System. In a more precise and complex definition, Linux is an open-source OS kernel on which a large variety of Operating Systems (known as Linux distributions) are built.",
#     "updated_at": 1392940800,
#     "url": "https://www.igdb.com/platforms/linux",
#     "versions": [
#       44
#     ],
#     "websites": [
#       1
#     ]
#   },
#   {
#     "id": 4,
#     "abbreviation": "N64",
#     "alternative_name": "N64",
#     "category": 1,
#     "created_at": 1297555200,
#     "generation": 5,
#     "name": "Nintendo 64",
#     "platform_logo": 260,
#     "product_family": 5,
#     "slug": "n64",
#     "updated_at": 1565136000,
# ...

# %%
data = response.json()
len(data)
# Out:
# 163

# %%
platforms = pd.DataFrame(data)
platforms.head()
# Out:
#    id abbreviation alternative_name  category  created_at  \
# 0   3        Linux        GNU/Linux       4.0  1297555200
# 1   4          N64              N64       1.0  1297555200
# 2   5          Wii       Revolution       1.0  1297555200
# 3   6           PC            mswin       4.0  1297555200
# 4   7          PS1              NaN       1.0  1297555200
#
#                      name  platform_logo  product_family   slug  \
# 0                   Linux           33.0             4.0  linux
# 1             Nintendo 64          260.0             5.0    n64
# 2                     Wii          326.0             5.0    wii
# 3  PC (Microsoft Windows)          203.0             NaN    win
# 4             PlayStation          278.0             1.0     ps
#
#                                              summary  updated_at  \
# 0  Linux is a free and open-source (FOSS/FLOSS) O...  1392940800
# 1                                                NaN  1565136000
# ...

# %%
platforms.to_csv('../datasets/platforms.csv')

# %% [markdown]
# ## Game Mode

# %%
url = "https://api-v3.igdb.com/game_modes"

payload = "fields *;\nlimit 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 5

# %%
game_mode = pd.DataFrame(data)
game_mode.head()
# Out:
#    id  created_at                                name  \
# 0   3  1298937600                        Co-operative
# 1   1  1298937600                       Single player
# 2   2  1298937600                         Multiplayer
# 3   5  1298937600  Massively Multiplayer Online (MMO)
# 4   4  1298937600                        Split screen
#
#                                slug  updated_at  \
# 0                      co-operative  1323216000
# 1                     single-player  1323216000
# 2                       multiplayer  1323216000
# 3  massively-multiplayer-online-mmo  1323216000
# 4                      split-screen  1323216000
#
#                                                  url
# 0       https://www.igdb.com/game_modes/co-operative
# 1      https://www.igdb.com/game_modes/single-player
# 2        https://www.igdb.com/game_modes/multiplayer
# 3  https://www.igdb.com/game_modes/massively-mult...
# 4       https://www.igdb.com/game_modes/split-screen

# %%
game_mode.to_csv('../datasets/game_mode.csv')

# %% [markdown]
# ## Time to Beat

# %%
url = "https://api-v3.igdb.com/time_to_beats"

payload = "fields *;\nlimit 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
time_beat = pd.DataFrame(data)
time_beat.head()
# Out:
#         id     game  normally  completely    hastly
# 0        8   6519.0   15720.0         NaN       NaN
# 1     1833   5082.0  234000.0         NaN       NaN
# 2    11397      NaN  217820.0    468000.0  108000.0
# 3     1172  14872.0     900.0         NaN       NaN
# 4     1282  13138.0   10800.0     10800.0       NaN
# ..     ...      ...       ...         ...       ...
# 495    926   7543.0   21600.0     54000.0       NaN
# 496     29      NaN       0.0     17460.0       0.0
# 497      5   6279.0   22320.0         NaN       NaN
# 498    515   8114.0    7200.0      8760.0       NaN
# 499   1379   1000.0       NaN     90000.0       NaN
#
# [500 rows x 5 columns]

# %% [markdown]
# ## Time to Beat Offset 500

# %%
url = "https://api-v3.igdb.com/time_to_beats"

payload = "fields *;\nlimit 500;\noffset 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
time_beat_2 = pd.DataFrame(data)
time_beat_2.head()
# Out:
#        id     game  normally  completely  hastly
# 0    1420   1990.0   14400.0         NaN     NaN
# 1    1428   1958.0       NaN     43200.0     NaN
# 2    1461   7057.0       NaN    180000.0     NaN
# 3     575   1443.0   76080.0    144000.0     NaN
# 4     535    431.0   34200.0         NaN     NaN
# ..    ...      ...       ...         ...     ...
# 495  1643  18011.0    8880.0         NaN     NaN
# 496  1649    396.0   13740.0         NaN     NaN
# 497  1654    419.0       NaN     52800.0     NaN
# 498  1064   3077.0       NaN    158400.0     NaN
# 499  1079   2287.0       NaN    720000.0     NaN
#
# [500 rows x 5 columns]

# %% [markdown]
# ## Time to Beat Offset 1000

# %%
url = "https://api-v3.igdb.com/time_to_beats"

payload = "fields *;\nlimit 500;\noffset 1000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
time_beat_3 = pd.DataFrame(data)
time_beat_3.head()
# Out:
#      id  completely    game  normally  hastly
# 0  1084    144000.0  1318.0   90000.0     NaN
# 1  1090         NaN   544.0   25200.0     NaN
# 2  1179         NaN  1063.0       NaN     NaN
# 3  1185         NaN  9630.0  216000.0     NaN
# 4  1705         NaN  5062.0   61200.0     NaN

# %% [markdown]
# ## Time to Beat Offset 1500

# %%
url = "https://api-v3.igdb.com/time_to_beats"

payload = "fields *;\nlimit 500;\noffset 1500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
time_beat_4 = pd.DataFrame(data)
time_beat_4.head()
# Out:
#      id     game  normally  completely  hastly
# 0  1586   9727.0   36600.0         NaN     NaN
# 1  1590  22439.0  432000.0    648000.0     NaN
# 2  1858   7477.0  258300.0         NaN     NaN
# 3  1955  12751.0   18000.0     28800.0     NaN
# 4   602   2591.0    3600.0         NaN     NaN

# %% [markdown]
# ## Time to Beat Offset 2000

# %%
url = "https://api-v3.igdb.com/time_to_beats"

payload = "fields *;\nlimit 500;\noffset 2000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 344

# %%
time_beat_5 = pd.DataFrame(data)
time_beat_5.head()
# Out:
#      id     game  normally  completely  hastly
# 0  2327  13199.0  100800.0         NaN     NaN
# 1   298     75.0   96180.0    146160.0     NaN
# 2   299   2064.0   10800.0     10800.0     NaN
# 3  2102    427.0  121140.0         NaN     NaN
# 4  2109  11056.0   43260.0     59880.0     NaN

# %% [markdown]
# ### Merge Time to Beat DataFrames

# %%
time_beat_final = pd.concat([time_beat,time_beat_2,time_beat_3,time_beat_4,time_beat_5])
time_beat_final.head()
# Out:
# /Users/tringuyen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    completely     game    hastly     id  normally
# 0         NaN   6519.0       NaN      8   15720.0
# 1         NaN   5082.0       NaN   1833  234000.0
# 2    468000.0      NaN  108000.0  11397  217820.0
# 3         NaN  14872.0       NaN   1172     900.0
# 4     10800.0  13138.0       NaN   1282   10800.0

# %%
time_beat_final.to_csv('../datasets/time_beat.csv')

# %% [markdown]
# ## Game Engines

# %%
url = "https://api-v3.igdb.com/game_engines"

payload = "fields *;\nlimit 500;\nwhere platforms = (48,49,130, 92);"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 32

# %%
game_engine = pd.DataFrame(data)
game_engine.head()
# Out:
#     id companies  created_at  logo               name            platforms  \
# 0  695   [13169]  1557360000  87.0                KEX  [3, 6, 14, 49, 130]
# 1  686   [18808]  1555027200   NaN              LSSDK         [6, 48, 165]
# 2  421    [9728]  1483056000  92.0  Amazon Lumberyard  [6, 34, 39, 48, 49]
# 3  681    [2952]  1554854400  85.0          KT Engine     [6, 48, 49, 130]
# 4  186    [5025]  1425427200  31.0            OEngine          [6, 48, 49]
#
#                 slug  updated_at  \
# 0                kex  1557532800
# 1              lssdk  1555459200
# 2  amazon-lumberyard  1572825600
# 3          kt-engine  1554854400
# 4            oengine  1425427200
#
#                                                  url
# 0              https://www.igdb.com/game_engines/kex
# 1            https://www.igdb.com/game_engines/lssdk
# 2  https://www.igdb.com/game_engines/amazon-lumbe...
# 3        https://www.igdb.com/game_engines/kt-engine
# ...

# %%
game_engine.to_csv('../datasets/game_engine.csv')

# %% [markdown]
# ## Franchise

# %%
url = "https://api-v3.igdb.com/franchises"

payload = "fields *;\nlimit 500;\n"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
franchise = pd.DataFrame(data)
franchise.head()
# Out:
#     id  created_at                 name                 slug  updated_at  \
# 0   20  1322611200  Beneath a Steel Sky  beneath-a-steel-sky  1323216000
# 1   43  1359676800   Dungeons & Dragons     dungeons-dragons  1359676800
# 2   61  1372550400            Spartacus            spartacus  1372550400
# 3  133  1381708800         Harry Potter         harry-potter  1381708800
# 4  237  1390521600                Shamu                shamu  1390521600
#
#                                                  url  \
# 0  https://www.igdb.com/franchises/beneath-a-stee...
# 1   https://www.igdb.com/franchises/dungeons-dragons
# 2          https://www.igdb.com/franchises/spartacus
# 3       https://www.igdb.com/franchises/harry-potter
# 4              https://www.igdb.com/franchises/shamu
#
#                                                games
# 0                                                NaN
# 1  [5, 6, 81, 82, 83, 84, 214, 216, 674, 753, 832...
# ...

# %% [markdown]
# ## Franchise Offset 500

# %%
url = "https://api-v3.igdb.com/franchises"

payload = "fields *;\nlimit 500;\noffset 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
franchise_2 = pd.DataFrame(data)
franchise_2.head()
# Out:
#    id  created_at                                              games  \
# 0  45  1360454400                                             [1919]
# 1  52  1372118400                                 [1282, 1283, 1287]
# 2  58  1372464000  [2313, 3789, 4681, 7757, 8501, 12242, 12888, 1...
# 3  72  1373155200                                      [2482, 13068]
# 4  73  1373155200                        [2500, 14695, 14698, 63826]
#
#                 name               slug  updated_at  \
# 0           Deadpool           deadpool  1360454400
# 1  Fables and Fiends  fables-and-fiends  1372118400
# 2            Asterix            asterix  1372464000
# 3      The Godfather      the-godfather  1373155200
# 4           Wizardry           wizardry  1373155200
#
#                                                  url
# 0           https://www.igdb.com/franchises/deadpool
# 1  https://www.igdb.com/franchises/fables-and-fiends
# 2            https://www.igdb.com/franchises/asterix
# ...

# %% [markdown]
# ## Franchise Offset 1000

# %%
url = "https://api-v3.igdb.com/franchises"

payload = "fields *;\nlimit 500;\noffset 1000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
franchise_3 = pd.DataFrame(data)
franchise_3.head()
# Out:
#      id  created_at             games                name               slug  \
# 0  1311  1532304000  [106040, 106041]  Aquanaut's Holiday  aquanauts-holiday
# 1   821  1466726400    [19765, 36730]             Berserk            berserk
# 2   362  1393545600            [5470]              11eyes             11eyes
# 3   372  1396310400            [5727]                Antz               antz
# 4   414  1398297600            [6434]               Herby              herby
#
#    updated_at                                                url
# 0  1532304000  https://www.igdb.com/franchises/aquanauts-holiday
# 1  1466726400            https://www.igdb.com/franchises/berserk
# 2  1393545600             https://www.igdb.com/franchises/11eyes
# 3  1396310400               https://www.igdb.com/franchises/antz
# 4  1398297600              https://www.igdb.com/franchises/herby

# %% [markdown]
# ## Franchise Offset 1500

# %%
url = "https://api-v3.igdb.com/franchises"

payload = "fields *;\nlimit 500;\noffset 1500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 25

# %%
franchise_4 = pd.DataFrame(data)
franchise_4.head()
# Out:
#      id  created_at     games                name                slug  \
# 0  1699  1578528000  [128068]  Sword of the Stars  sword-of-the-stars
# 1  1700  1578700800       NaN              towaga              towaga
# 2  1701  1578960000       NaN           Surviving           surviving
# 3  1702  1578960000       NaN             Control             control
# 4  1703  1579478400       NaN      Ядерный титбит    iadiernyi-titbit
#
#    updated_at                                                url
# 0  1578528000  https://www.igdb.com/franchises/sword-of-the-s...
# 1  1578700800             https://www.igdb.com/franchises/towaga
# 2  1578960000          https://www.igdb.com/franchises/surviving
# 3  1578960000            https://www.igdb.com/franchises/control
# 4  1579478400   https://www.igdb.com/franchises/iadiernyi-titbit

# %% [markdown]
# ## Merge Franchise DataFrames

# %%
franchise_final = pd.concat([franchise,franchise_2,franchise_3,franchise_4])
franchise_final.head()
# Out:
# /Users/tringuyen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    created_at                                              games   id  \
# 0  1322611200                                                NaN   20
# 1  1359676800  [5, 6, 81, 82, 83, 84, 214, 216, 674, 753, 832...   43
# 2  1372550400                                             [2326]   61
# 3  1381708800  [341, 3011, 3149, 3150, 3941, 3942, 3943, 3944...  133
# 4  1390521600                                             [4099]  237
#
#                   name                 slug  updated_at  \
# 0  Beneath a Steel Sky  beneath-a-steel-sky  1323216000
# ...

# %%
franchise_final.to_csv('../datasets/franchise.csv')

# %% [markdown]
# ## Character

# %%
url = "https://api-v3.igdb.com/characters"

payload = "fields *;\nlimit 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
character = pd.DataFrame(data)
character.head()
# Out:
#       id  created_at     games             name    people             slug  \
# 0  12782  1551398400   [10232]          Delores  [185588]          delores
# 1  12690  1547337600   [14389]  Chad Kensington   [30938]  chad-kensington
# 2  11079  1510099200     [207]     Ludger Brink  [154231]     ludger-brink
# 3  14296  1559260800  [101211]  Authority Elite  [206849]  authority-elite
# 4  11563  1520812800   [68461]     Oda Nobunaga  [162315]     oda-nobunaga
#
#    updated_at                                              url akas  \
# 0  1551398400          https://www.igdb.com/characters/delores  NaN
# 1  1547337600  https://www.igdb.com/characters/chad-kensington  NaN
# 2  1510099200     https://www.igdb.com/characters/ludger-brink  NaN
# 3  1559260800  https://www.igdb.com/characters/authority-elite  NaN
# 4  1520812800     https://www.igdb.com/characters/oda-nobunaga  NaN
#
#   description  gender  mug_shot  species
# 0         NaN     NaN       NaN      NaN
# ...

# %% [markdown]
# ## Character Offset 500

# %%
url = "https://api-v3.igdb.com/characters"

payload = "fields *;\nlimit 500;\noffset 500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
character_2 = pd.DataFrame(data)
character_2.head()
# Out:
#       id  created_at                                   games          name  \
# 0   2921  1418428800                                  [2583]       Kid Buu
# 1   2942  1418428800  [4846, 5540, 7518, 7859, 11367, 13232]     Bartender
# 2   8306  1462924800                                     NaN        Maiden
# 3  14326  1559260800                                 [24262]     King Orde
# 4   8974  1464998400                                     NaN  Twisted Fate
#
#                                               people          slug  \
# 0                                     [45760, 45777]       kid-buu
# 1  [456, 46048, 46053, 70518, 115192, 133102, 143...     bartender
# 2                                             [7081]        maiden
# 3                                           [207008]     king-orde
# 4                                            [46045]  twisted-fate
#
#    updated_at                                           url  gender  mug_shot  \
# ...

# %% [markdown]
# ## Character Offset 1000

# %%
url = "https://api-v3.igdb.com/characters"

payload = "fields *;\nlimit 500;\noffset 1000;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
character_3 = pd.DataFrame(data)
character_3.head()
# Out:
#      id  created_at               games              name  \
# 0  4634  1431993600               [897]  Magnus Armstrong
# 1  4669  1431993600               [786]     Jen McQuarrie
# 2  9981  1475020800              [2444]             Duram
# 3  8064  1462579200  [1221, 1224, 2933]              Chip
# 4  5034  1432944000       [5845, 27283]         Soldier C
#
#                    people              slug  updated_at  \
# 0                 [79292]  magnus-armstrong  1431993600
# 1                 [79689]     jen-mcquarrie  1431993600
# 2                [138443]             duram  1475020800
# 3          [10564, 31745]              chip  1555977600
# 4  [20749, 40322, 201251]         soldier-c  1555977600
#
#                                                 url  gender  mug_shot  \
# 0  https://www.igdb.com/characters/magnus-armstrong     NaN       NaN
# 1     https://www.igdb.com/characters/jen-mcquarrie     NaN       NaN
# ...

# %% [markdown]
# ## Character Offset 1500

# %%
url = "https://api-v3.igdb.com/characters"

payload = "fields *;\nlimit 500;\noffset 1500;"
headers = {
    'cookie': "__cfduid=d90176446fc57ac62790618a36aff52581583171630",
    'user-key': "3478fe97fbb6ea8c83bd8d68d22b1770",
    'content-type': "application/json"
    }

response = requests.request("GET", url, data=payload, headers=headers)

# %%
data = response.json()
len(data)
# Out:
# 500

# %%
character_4 = pd.DataFrame(data)
character_4.head()
# Out:
#       id  created_at           name    people           slug  updated_at  \
# 0  11210  1517011200        Hobbits  [115085]        hobbits  1517011200
# 1  11212  1517011200  Elena Shapiro  [115085]  elena-shapiro  1517011200
# 2  11218  1517011200  Tutorial Unit  [144485]  tutorial-unit  1517011200
# 3   1620  1410652800    Wang Ziyang   [23430]    wang-ziyang  1417219200
# 4   1623  1410652800  Helen Dawkins   [23433]  helen-dawkins  1417219200
#
#                                              url   games akas  gender  \
# 0        https://www.igdb.com/characters/hobbits     NaN  NaN     NaN
# 1  https://www.igdb.com/characters/elena-shapiro     NaN  NaN     NaN
# 2  https://www.igdb.com/characters/tutorial-unit     NaN  NaN     NaN
# 3    https://www.igdb.com/characters/wang-ziyang  [1342]  NaN     NaN
# 4  https://www.igdb.com/characters/helen-dawkins  [1342]  NaN     NaN
#
#    mug_shot  species description
# 0       NaN      NaN         NaN
# 1       NaN      NaN         NaN
# ...
