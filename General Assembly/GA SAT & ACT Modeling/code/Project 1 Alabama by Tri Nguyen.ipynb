# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat = pd.read_csv('../data/sat_2017.csv')
act = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
sat
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
act
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# Answer: For the sat datasets, there seems to be a higher total with lower participations. Total is summing up the Math and Reading Scores. Integers, strings, and special characters data types exist here.
#
# For the act datasets, the composite score averages the English, Math, Reading, and Science scores. The national score is included in data set adding an extra row. Float, strings, and special characters data types exist here.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Yes

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: No obvious issues except for Wyoming's composite 20.x score.
#
# For SAT, the minimum and  maximum score is 400 and 1600 respectively and the ACT is scored between 1 to 36.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: The Sat pariticpation rates shows as percentages in the data frame but is consiered an object. This should be an integer or float.
#
# The ACT partcipation rates and the composite scores should also be an integer or floats and not objects.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#act['Participation'].astype(object).head() #checking how astype() works

#map(astype(object).act['Participation']) #little success with mapping

#pd.to_numeric(act['Participation']) #converting column to data type unsuccessful

#act['Participation'].head() #checking data type

#act['Participation'].str.strip('%').head() #inserted str before strip delivered result

#pd.to_numeric(act['Participation'].str.strip('%'))/100 #replaced float function with pd.to_numeric function with sucess

# %%
#code
#may not need for loop if df['column'] is inserted as variable
def p2n(x):    
    y = pd.to_numeric(x.strip('%'))/100
    return y

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
sat['Participation'].head()
# Out:
# 0     5%
# 1    38%
# 2    30%
# 3     3%
# 4    53%
# Name: Participation, dtype: object

# %%
sat['Participation'] = sat['Participation'].map(p2n)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act['Participation']= act['Participation'].map(p2n)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
display(sat.info())
display(act.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB
# None

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
#ufo.columns = ufo.columns.str.lower()
sat.columns = sat.columns.str.lower()

# %%
sat.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
#ufo.rename(columns={"colors reported": "colors", "shape reported": "shape"}, inplace=True)
#ufo.head()
sat.rename(columns={"participation":"sat_participation_rates",
                    "evidence-based reading and writing":"reading_and_writing",
                   "math":"sat_math"}, inplace=True)
display(sat.head())
display(sat.info())
# Out:
#         state  sat_participation_rates  reading_and_writing  sat_math  total
# 0     Alabama                     0.05                  593       572   1165
# 1      Alaska                     0.38                  547       533   1080
# 2     Arizona                     0.30                  563       553   1116
# 3    Arkansas                     0.03                  614       594   1208
# 4  California                     0.53                  531       524   1055
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                      51 non-null object
# sat_participation_rates    51 non-null float64
# reading_and_writing        51 non-null int64
# sat_math                   51 non-null int64
# total                      51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# None

# %%
act.columns = act.columns.str.lower()

# %%
act.head()
# Out:
#       state  participation  english  math  reading  science composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
act.rename(columns={"participation":"act_participation_rates",
                    "evidence-based reading and writing":"reading_and_writing",
                    "math":"act_math"
                   }, inplace=True)
display(act.head())
display(act.info())
# Out:
#       state  act_participation_rates  english  act_math  reading  science  \
# 0  National                     0.60     20.3      20.7     21.4     21.0
# 1   Alabama                     1.00     18.9      18.4     19.7     19.4
# 2    Alaska                     0.65     18.7      19.8     20.4     19.9
# 3   Arizona                     0.62     18.6      19.8     20.1     19.8
# 4  Arkansas                     1.00     18.9      19.0     19.7     19.5
#
#   composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# state                      52 non-null object
# act_participation_rates    52 non-null float64
# english                    52 non-null float64
# act_math                   52 non-null float64
# reading                    52 non-null float64
# science                    52 non-null float64
# composite                  52 non-null object
# ...

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# ## SAT
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT/ACT|List of states in the United States, plus Washington D.C.|
# |sat_participation_rates|float|SAT|The participation rate of students within the state who took the SAT exam.|
# |reading_and_writing|integer|SAT|The average Reading and Writing score of the SAT exam within the state.|
# |sat_math|integer|SAT|The average Math score of the SAT exam within the state.|
# |total|integer|SAT|The sum total score of the SAT exam within the state.|
#
# ## ACT
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT/ACT|List of states in the United States, plus Washington D.C.|
# |act_participation_rates|float|ACT|The participation rate of students within the state who took the ACT exam.|
# |english|float|ACT|The average English score of the ACT exam within the state.|
# |act_math|float|ACT|The average Math score of the ACT exam within the state.|
# |reading|float|ACT|The average Reading score of the ACT exam within the state.|
# |science|float|ACT|The average Science score of the ACT exam within the state.|
# |composite|object|ACT|The sum total score of the ACT exam within the state.|

# %%
display(sat.info())
display(act.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# state                      51 non-null object
# sat_participation_rates    51 non-null float64
# reading_and_writing        51 non-null int64
# sat_math                   51 non-null int64
# total                      51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# state                      52 non-null object
# act_participation_rates    52 non-null float64
# english                    52 non-null float64
# act_math                   52 non-null float64
# reading                    52 non-null float64
# science                    52 non-null float64
# composite                  52 non-null object
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB
# None

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
# 0 row containing National in the ACT scores is extra
display(sat)
display(act)
# Out:
#                    state  sat_participation_rates  reading_and_writing  \
# 0                Alabama                     0.05                  593
# 1                 Alaska                     0.38                  547
# 2                Arizona                     0.30                  563
# 3               Arkansas                     0.03                  614
# 4             California                     0.53                  531
# 5               Colorado                     0.11                  606
# 6            Connecticut                     1.00                  530
# 7               Delaware                     1.00                  503
# 8   District of Columbia                     1.00                  482
# 9                Florida                     0.83                  520
# 10               Georgia                     0.61                  535
# 11                Hawaii                     0.55                  544
# ...

# %%
#drop() = remove,delete
act.drop(0, inplace= True)

# %%
act.head()
# Out:
#         state  act_participation_rates  english  act_math  reading  science  \
# 1     Alabama                     1.00     18.9      18.4     19.7     19.4
# 2      Alaska                     0.65     18.7      19.8     20.4     19.9
# 3     Arizona                     0.62     18.6      19.8     20.1     19.8
# 4    Arkansas                     1.00     18.9      19.0     19.7     19.5
# 5  California                     0.31     22.5      22.7     23.1     22.2
#
#   composite
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
#movie_reviews = pd.merge(ratings, movies, how='left')
#movie_reviews.head()

test_reviews_2017 = pd.merge(sat,act, how='right')
test_reviews_2017
# Out:
#                    state  sat_participation_rates  reading_and_writing  \
# 0                Alabama                     0.05                  593
# 1                 Alaska                     0.38                  547
# 2                Arizona                     0.30                  563
# 3               Arkansas                     0.03                  614
# 4             California                     0.53                  531
# 5               Colorado                     0.11                  606
# 6            Connecticut                     1.00                  530
# 7               Delaware                     1.00                  503
# 8   District of Columbia                     1.00                  482
# 9                Florida                     0.83                  520
# 10               Georgia                     0.61                  535
# 11                Hawaii                     0.55                  544
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
pwd
# Out:
# '/Users/tringuyen/Desktop/ga/Projects/project_1/code'

# %%
#code
test_reviews_2017.to_csv('/Users/tringuyen/Desktop/ga/Projects/project_1/data/combined_2017.csv')

# %% [markdown]
# ## (PDF Optional) 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#test_reviews_2017 = pd.merge(sat,act, how='right')
#test_reviews_2017.head()
sat_2018 = pd.read_csv('../data/sat_2018.csv')#reading csv files as a variable
act_2018 = pd.read_csv('../data/act_2018.csv')

sat_2018['Participation'] = sat_2018['Participation'].map(p2n) #converting into integers
act_2018['Participation'] = act_2018['Participation'].map(p2n)

sat_2018.columns = sat_2018.columns.str.lower() #lowercase the column names
act_2018.columns = act_2018.columns.str.lower()

sat_2018.rename(columns={"participation":"sat_participation_rates",
                    "evidence-based reading and writing":"reading_and_writing",
                         "math":"sat_math"
                    }, inplace=True)
act_2018.rename(columns={"participation":"act_participation_rates",
                         "math":"act_math"
                   }, inplace=True)

act_2018.drop(19, inplace= True) #remove the extra Maine entry

test_reviews_2018 = pd.merge(sat_2018,act_2018, how = 'right')

test_reviews_2018.to_csv('/Users/tringuyen/Desktop/ga/Projects/project_1/data/combined_2018.csv')

display(test_reviews_2018.head())
display(sat_2018.head())
display(act_2018)
# Out:
#         state  sat_participation_rates  reading_and_writing  sat_math   total  \
# 0     Alabama                     0.06                595.0     571.0  1166.0
# 1      Alaska                     0.43                562.0     544.0  1106.0
# 2     Arizona                     0.29                577.0     572.0  1149.0
# 3    Arkansas                     0.05                592.0     576.0  1169.0
# 4  California                     0.60                540.0     536.0  1076.0
#
#    act_participation_rates  composite
# 0                     1.00       19.1
# 1                     0.33       20.8
# 2                     0.66       19.2
# 3                     1.00       19.4
# 4                     0.27       22.7
#         state  sat_participation_rates  reading_and_writing  sat_math  total
# 0     Alabama                     0.06                  595       571   1166
# 1      Alaska                     0.43                  562       544   1106
# ...

# %%
display(test_reviews_2017.info)
display(test_reviews_2018.info)
# Out:
# <bound method DataFrame.info of                    state  sat_participation_rates  reading_and_writing  \
# 0                Alabama                     0.05                  593
# 1                 Alaska                     0.38                  547
# 2                Arizona                     0.30                  563
# 3               Arkansas                     0.03                  614
# 4             California                     0.53                  531
# 5               Colorado                     0.11                  606
# 6            Connecticut                     1.00                  530
# 7               Delaware                     1.00                  503
# 8   District of Columbia                     1.00                  482
# 9                Florida                     0.83                  520
# 10               Georgia                     0.61                  535
# 11                Hawaii                     0.55                  544
# ...

# %%
combined_tests = pd.concat([test_reviews_2017,test_reviews_2018],sort=False) #Nan shows up at bottom rows
combined_tests
# Out:
#                    state  sat_participation_rates  reading_and_writing  \
# 0                Alabama                     0.05                593.0
# 1                 Alaska                     0.38                547.0
# 2                Arizona                     0.30                563.0
# 3               Arkansas                     0.03                614.0
# 4             California                     0.53                531.0
# ..                   ...                      ...                  ...
# 46            Washington                     0.69                543.0
# 47         West Virginia                     0.28                513.0
# 48             Wisconsin                     0.03                641.0
# 49               Wyoming                     0.03                633.0
# 50  District of columbia                      NaN                  NaN
#
#     sat_math   total  act_participation_rates  english  act_math  reading  \
# ...

# %%
combined_tests.to_csv('/Users/tringuyen/Desktop/ga/Projects/project_1/data/final.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-128-0574f86f758e> in <module>
# ----> 1 combined_tests.to_csv('./project_1/data/final.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:

combined_tests.describe()
# Out:
#        sat_participation_rates  reading_and_writing    sat_math        total  \
# count               101.000000           101.000000  101.000000   101.000000
# mean                  0.422871           567.089109  552.643564  1124.504950
# std                   0.360961            46.150428   68.647882    92.218287
# min                   0.020000           480.000000   52.000000   950.000000
# 25%                   0.040000           535.000000  523.000000  1056.000000
# 50%                   0.430000           555.000000  547.000000  1099.000000
# 75%                   0.700000           614.000000  595.000000  1210.000000
# max                   1.000000           644.000000  655.000000  1298.000000
#
#        act_participation_rates    english   act_math    reading    science
# count               102.000000  51.000000  51.000000  51.000000  51.000000
# mean                  0.634902  20.931373  21.182353  22.013725  21.041176
# ...

# %%
display(test_reviews_2017.describe())
display(test_reviews_2018.describe())
# Out:
#        sat_participation_rates  reading_and_writing    sat_math        total  \
# count                51.000000            51.000000   51.000000    51.000000
# mean                  0.398039           569.117647  547.627451  1126.098039
# std                   0.352766            45.666901   84.909119    92.494812
# min                   0.020000           482.000000   52.000000   950.000000
# 25%                   0.040000           533.500000  522.000000  1055.500000
# 50%                   0.380000           559.000000  548.000000  1107.000000
# 75%                   0.660000           613.000000  599.000000  1212.000000
# max                   1.000000           644.000000  651.000000  1295.000000
#
#        act_participation_rates    english   act_math    reading    science
# count                51.000000  51.000000  51.000000  51.000000  51.000000
# mean                  0.652549  20.931373  21.182353  22.013725  21.041176
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
import math
def std(x):
    std = math.sqrt(mean(abs(x - x.mean())**2))
    return std

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
{std(x) for x in combined_tests['sat_participation_rates']}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-3faeaa3237a4> in <module>
#       1 #Code:
# ----> 2 {std(x) for x in combined_tests['sat_participation_rates']}
#
# <ipython-input-105-3faeaa3237a4> in <setcomp>(.0)
#       1 #Code:
# ----> 2 {std(x) for x in combined_tests['sat_participation_rates']}
#
# <ipython-input-104-4df9072b3f35> in std(x)
#       2 import math
#       3 def std(x):
# ----> 4     std = math.sqrt(mean(abs(x - x.mean())**2))
#       5     return std
#
# NameError: name 'mean' is not defined

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code
display(test_reviews_2017.sort_values('sat_participation_rates').head()) #min to max
display(test_reviews_2017.sort_values('sat_participation_rates',ascending = False).head()) #max to min
display(test_reviews_2018.sort_values('sat_participation_rates').head()) #min to max
display(test_reviews_2018.sort_values('sat_participation_rates',ascending = False).head()) #max to min
# Out:
#            state  sat_participation_rates  reading_and_writing  sat_math  \
# 34  North Dakota                     0.02                  635       621
# 24   Mississippi                     0.02                  634       607
# 15          Iowa                     0.02                  641       635
# 25      Missouri                     0.03                  640       631
# 44          Utah                     0.03                  624       614
#
#     total  act_participation_rates  english  act_math  reading  science  \
# 34   1256                     0.98     19.0      20.4     20.5     20.6
# 24   1242                     1.00     18.2      18.1     18.8     18.8
# 15   1275                     0.67     21.2      21.3     22.6     22.1
# 25   1271                     1.00     19.8      19.9     20.8     20.5
# 44   1238                     1.00     19.5      19.9     20.8     20.6
#
#    composite
# 34      20.3
# 24      18.6
# 15      21.9
# 25      20.4
# 44      20.3
# ...

# %% [markdown]
# For SAT 2017, District of Columbia, Michigian, and Connecticut have the highest participation rates and North Dakota, Mississippi, and Iowa have the lowest participation rates.
#
# For SAT 2018, Idaho, Colorado, and Connecticut have the highest participation rates, and North Dakota, Wyoming, and South Dakota have the lowest participation rates.

# %%
display(test_reviews_2017.sort_values('act_participation_rates').head()) #min to max
display(test_reviews_2017.sort_values('act_participation_rates',ascending = False).head()) #max to min
display(test_reviews_2018.sort_values('act_participation_rates').head()) #min to max
display(test_reviews_2018.sort_values('act_participation_rates',ascending = False).head()) #max to min
# Out:
#             state  sat_participation_rates  reading_and_writing  sat_math  \
# 19          Maine                     0.95                  513       499
# 29  New Hampshire                     0.96                  532       520
# 7        Delaware                     1.00                  503       492
# 39   Rhode Island                     0.71                  539       524
# 38   Pennsylvania                     0.65                  540       531
#
#     total  act_participation_rates  english  act_math  reading  science  \
# 19   1012                     0.08     24.2      24.0     24.8     23.7
# 29   1052                     0.18     25.4      25.1     26.0     24.9
# 7     996                     0.18     24.1      23.4     24.8     23.6
# 39   1062                     0.21     24.0      23.3     24.7     23.4
# 38   1071                     0.23     23.4      23.4     24.2     23.3
#
#    composite
# 19      24.3
# 29      25.5
# 7       24.1
# 39      24.0
# 38      23.7
# ...

# %% [markdown]
# For ACT 2017, Alabama, Kentucky, and Wisconsin have the highest participation rates, and Maine, New Hampshire, and Delware have the lowest participation rates.
#
# For ACT 2018, Alabama, Kentucky, and Wyoming have the highest participation rates, and Maine, Rhode Island, and New Hampshire have the lowest participation rates.

# %%
display(test_reviews_2017.sort_values('total').head()) #min to max
display(test_reviews_2017.sort_values('total',ascending = False).head()) #max to min
display(test_reviews_2018.sort_values('total').head()) #min to max
display(test_reviews_2018.sort_values('total',ascending = False).head()) #max to min
# Out:
#                    state  sat_participation_rates  reading_and_writing  \
# 8   District of Columbia                     1.00                  482
# 7               Delaware                     1.00                  503
# 12                 Idaho                     0.93                  513
# 22              Michigan                     1.00                  509
# 19                 Maine                     0.95                  513
#
#     sat_math  total  act_participation_rates  english  act_math  reading  \
# 8        468    950                     0.32     24.4      23.5     24.9
# 7        492    996                     0.18     24.1      23.4     24.8
# 12       493   1005                     0.38     21.9      21.8     23.0
# 22       495   1005                     0.29     24.1      23.7     24.5
# 19       499   1012                     0.08     24.2      24.0     24.8
#
#     science composite
# 8      23.5      24.2
# 7      23.6      24.1
# 12     22.1      22.3
# ...

# %% [markdown]
# For SAT 2017, District of Columbia, Delaware, Idaho have the lowest total scores while Minnesota, Wisconsin, and Iowa have the highest total scores.
#
# For SAT 2018, Delaware, West Virginia, and Idaho have the lowest total scores while Minnesota, Wisconsin, and North Dakota have the highest total scores.

# %%
display(test_reviews_2017.sort_values('composite').head()) #min to max
display(test_reviews_2017.sort_values('composite',ascending = False).head()) #max to min
display(test_reviews_2018.sort_values('composite').head()) #min to max
display(test_reviews_2018.sort_values('composite',ascending = False).head()) #max to min
# Out:
#              state  sat_participation_rates  reading_and_writing  sat_math  \
# 28          Nevada                     0.26                  563       553
# 24     Mississippi                     0.02                  634       607
# 40  South Carolina                     0.50                  543       521
# 11          Hawaii                     0.55                  544       541
# 33  North Carolina                     0.49                  546       535
#
#     total  act_participation_rates  english  act_math  reading  science  \
# 28   1116                      1.0     16.3      18.0     18.1     18.2
# 24   1242                      1.0     18.2      18.1     18.8     18.8
# 40   1064                      1.0     17.5      18.6     19.1     18.9
# 11   1085                      0.9     17.8      19.2     19.2     19.3
# 33   1081                      1.0     17.8      19.3     19.6     19.3
#
#    composite
# 28      17.8
# 24      18.6
# 40      18.7
# 11      19.0
# ...

# %% [markdown]
# For ACT 2017, Nevada, Mississippi, and South Carolina have the lowest composite scores while New Hampshire, Massachusetts, and Conniticut have the highest composite scores.
#
# For ACT 2018, Nevada, South Carolina, and Mississippi have the lowest composite scores while Connecticut, Massachusetts, and New Hampshire have the highest composite scores.

# %%
#Do any states with 100% participation on a given test have a rate change year-to-year?
display(test_reviews_2017.sort_values('sat_participation_rates',ascending = False).head(10)) #max to min
display(test_reviews_2018.sort_values('sat_participation_rates',ascending = False).head(10)) #max to min

display(test_reviews_2017.sort_values('act_participation_rates',ascending = False).head(10)) #max to min
display(test_reviews_2018.sort_values('act_participation_rates',ascending = False).head(10)) #max to min
# Out:
#                    state  sat_participation_rates  reading_and_writing  \
# 8   District of Columbia                     1.00                  482
# 22              Michigan                     1.00                  509
# 6            Connecticut                     1.00                  530
# 7               Delaware                     1.00                  503
# 29         New Hampshire                     0.96                  532
# 19                 Maine                     0.95                  513
# 12                 Idaho                     0.93                  513
# 9                Florida                     0.83                  520
# 21         Massachusetts                     0.76                  555
# 39          Rhode Island                     0.71                  539
#
#     sat_math  total  act_participation_rates  english  act_math  reading  \
# 8        468    950                     0.32     24.4      23.5     24.9
# ...

# %% [markdown]
# **Do any states with 100% participation on a given test have a rate change year-to-year?**
#
# For SAT, District of Columbia and New Hampshire have a rate change.
#
# For ACT, there were no rate change for states with a 100% participation rate.
#
#
# **Do any states show have >50% participation on both tests either year?**
# No states have >50% on both tests.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns

# %%
ax = plt.axes()
sns.heatmap(combined_tests.corr())
ax.set_title('2017-2018 SAT & ACT Test Subject Corelation ')
plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/SAT_ACT_heatmap.png')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code
subplot_histograms(combined_tests,
                   ['sat_participation_rates','act_participation_rates'],
                   ['SAT','ACT'], 
                   ['SAT Participation Rates','ACT Participation Rates'])

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/combined_tests_part_hist.png')

# %% [markdown]
# There are more participation for ACT than for SAT

# %%
subplot_histograms(combined_tests,
                   ['sat_math','act_math'],
                   ['SAT','ACT'], 
                   ['SAT Math','ACT Math'])

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/combined_tests_math_hist.png')

# %% [markdown]
# There are more SAT tests condensed in the higher region than there are ACT scores spread out.

# %%
subplot_histograms(combined_tests,
                   ['reading_and_writing','reading'],
                   ['SAT','ACT'], 
                   ['SAT Reading and Writing','ACT Reading'])

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/combined_tests_reading_hist.png')

# %% [markdown]
# The scores similar for the reading/writing portion of both tests.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
plt.figure()
plt.scatter(test_reviews_2017['sat_math'],
           test_reviews_2017['act_math'])

plt.title('SAT vs. ACT Math Scores 2017')
plt.xlabel('SAT Math')
plt.ylabel('ACT Math')
# plt.legend()
plt.show()
plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/sat_act_math_2017.png')
;
# Out:
# ''

# %%
plt.figure()
plt.scatter(test_reviews_2017['reading_and_writing'],
           test_reviews_2017['reading'])

plt.title('SAT vs. ACT Reading & Writing Scores 2017')
plt.xlabel('SAT Reading & Writing')
plt.ylabel('ACT Reading')
# plt.legend()
plt.show()

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/sat_act_reading_2017.png')
;
# Out:
# ''

# %%
plt.figure()
plt.scatter(test_reviews_2017['total'],
           test_reviews_2017['composite'])

plt.title('SAT Total vs. ACT Composite Scores 2017')
plt.xlabel('SAT Total')
plt.ylabel('ACT Composite')
# plt.legend()
plt.tight_layout(-12)

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/sat_act_total_2017.png')
;
# Out:
# ''

# %%
plt.figure()
plt.scatter(test_reviews_2017['total'],
           test_reviews_2018['total'])

plt.title('SAT Total 2017 vs. SAT Total 2018 Scores')
plt.xlabel('SAT Total 2017')
plt.ylabel('SAT Total 2018')
# plt.legend()
#plt.tight_layout(-12)

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/sat_total__2017_2018.png')
;
# Out:
# ''

# %%
plt.scatter(test_reviews_2017['composite'],
           test_reviews_2017['composite'])

plt.title('ACT Total 2017 vs. ACT Total 2018 Scores')
plt.xlabel('ACT Composite 2017')
plt.ylabel('ACT Composite 2018')
plt.tight_layout(-34)

plt.savefig('/Users/tringuyen/Desktop/ga/Projects/project_1/plots/act_composite_2017_2018.png')
;
# Out:
# ''

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
#https://python-graph-gallery.com/32-custom-boxplot-appearance-seaborn/
# library & dataset
#import seaborn as sns
#df = sns.load_dataset('iris')
 
# Change line width
#sns.boxplot( x=df["species"], y=df["sepal_length"], linewidth=5)
#sns.plt.show()

df = sns.load_dataset('test_reviews_2017')
sns.boxplot( x=df['states'], y=df['total'], linewidth=5)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-123-04dfa1ff4df1> in <module>
#       9 #sns.plt.show()
#      10
# ---> 11 df = sns.load_dataset('test_reviews_2017')
#      12 sns.boxplot( x=df['states'], y=df['total'], linewidth=5)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# ~/opt/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# It was interesting to see that there are more sat participations among the northeastern states. On the other hand, there are more act participation among the other states including the south. It be interesting to see correlation sat and act subjects. However, the numeric values and and scoring scale is so varied, it would be inaccurate to assume a higher score in one test is better than the other.

# %%
act.head()
# Out:
#         state  act_participation_rates  english  act_math  reading  science  \
# 1     Alabama                     1.00     18.9      18.4     19.7     19.4
# 2      Alaska                     0.65     18.7      19.8     20.4     19.9
# 3     Arizona                     0.62     18.6      19.8     20.1     19.8
# 4    Arkansas                     1.00     18.9      19.0     19.7     19.5
# 5  California                     0.31     22.5      22.7     23.1     22.2
#
#   composite
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## (Optional) Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Alabama, Kentucky, Wyoming seem to have consistent active participation in ACT.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Northeastern states tend to have the highest participation in the SAT test while the other states including the south and west coast have the highest participation in the ACT test.
#
# Alabama is an example of a southern state with a low SAT participation rate and a high ACT participation rate. Alabama being one of the poorest states may benefit with being provided free SAT testing to its public school as the ACT has done so already.
#
# Taking both tests only increases the chance of getting into college by either scoring better one test or being deligint and taking multiple exams.
