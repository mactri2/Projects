# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('lr_example').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-1-0d4ace7ad521> in <module>
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.appName('lr_example').getOrCreate()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/session.py in getOrCreate(self)
#     171                     for key, value in self._options.items():
#     172                         sparkConf.set(key, value)
# --> 173                     sc = SparkContext.getOrCreate(sparkConf)
#     174                     # This SparkContext may be an existing one.
#     175                     for key, value in self._options.items():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/context.py in getOrCreate(cls, conf)
#     365         with SparkContext._lock:
#     366             if SparkContext._active_spark_context is None:
# ...

# %%
from pyspark
